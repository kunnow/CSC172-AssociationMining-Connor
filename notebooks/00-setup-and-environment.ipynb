# %% [markdown]
# # 00 - Setup & Environment
#
# This notebook verifies the environment and the presence of the final dataset.

# %%
# Basic environment checks
# install required packages in the notebook environment if missing
# %pip install -q pandas numpy matplotlib

import sys
import platform

print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
import pandas as pd, numpy as np
import matplotlib, matplotlib.pyplot as plt

# use matplotlib to avoid "plt is not accessed" warnings
plt.style.use("default")

print("Python:", sys.version.split()[0])
print("Platform:", platform.platform())
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("matplotlib:", matplotlib.__version__)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Python: 3.11.0
# Platform: Windows-10-10.0.26200-SP0
# Python: 3.11.0
# Platform: Windows-10-10.0.26200-SP0
# pandas: 2.3.3
# numpy: 2.3.5
# matplotlib: 3.10.8
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Confirm final dataset path exists (relative paths)
from pathlib import Path
data_path = Path("../data/raw/final/phishing_email.csv")
print("Looking for:", data_path.resolve())
print("Exists:", data_path.exists())
# Out:
# Looking for: C:\Users\jradl\OneDrive\Documents\CSC172\CSC172-AssociationMining-Connor\data\raw\final\phishing_email.csv
# Exists: True

# %% [markdown]
# # Confirm final dataset path exists (relative paths)
# from pathlib import Path
# data_path = Path("../data/raw/final/phishing_email.csv")
# print("Looking for:", data_path.resolve())
# print("Exists:", data_path.exists())

# %% [markdown]
# **If `Exists` is False**: place your combined dataset at `data/raw/final/phishing_email.csv`.
# If you need to install dependencies, use `pip install -r ../requirements.txt` from the project root.
